# %% [markdown]
# ## Рекомендация тарифов

# %% [markdown]
# В вашем распоряжении данные о поведении клиентов, которые уже перешли на эти тарифы (из проекта курса «Статистический анализ данных»). Нужно построить модель для задачи классификации, которая выберет подходящий тариф. Предобработка данных не понадобится — вы её уже сделали.
#
# Постройте модель с максимально большим значением accuracy. Чтобы сдать проект успешно, нужно довести долю правильных ответов по крайней мере до 0.75. Проверьте accuracy на тестовой выборке самостоятельно.

# %% [markdown]
# ### Структура данных:

# %% [markdown]
# + сalls — количество звонков,
# + minutes — суммарная длительность звонков в минутах,
# + messages — количество sms-сообщений,
# + mb_used — израсходованный интернет-трафик в Мб,
# + is_ultra — каким тарифом пользовался в течение месяца («Ультра» — 1, «Смарт» — 0).

# %% [markdown]
# ### План работы:

# %% [markdown]
# 1. Изучить файл с данными.
# 2. Разбить данные на три выборки: обучающая, валидационная и тестовая.
# 3. Исследовать три модели классификации: Решающее дерево, Случайный лес и Логистическая регрессия.
# 4. Найти оптимальные параметры для каждой модели и выбрать одну из них для обучения модели.
# 5. Оценить точность обученной модели.
# 6. Оценить адекватность модели.

# %% [markdown]
# ### 1.Изучаем данные:

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://code.s3.yandex.net/datasets/users_behavior.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3214 entries, 0 to 3213
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   calls     3214 non-null   float64
#  1   minutes   3214 non-null   float64
#  2   messages  3214 non-null   float64
#  3   mb_used   3214 non-null   float64
#  4   is_ultra  3214 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 125.7 KB

# %%
df.head()
# Out:
#    calls  minutes  messages   mb_used  is_ultra
# 0   40.0   311.90      83.0  19915.42         0
# 1   85.0   516.75      56.0  22696.96         0
# 2   77.0   467.66      86.0  21060.45         0
# 3  106.0   745.53      81.0   8437.39         1
# 4   66.0   418.74       1.0  14502.75         0

# %% [markdown]
# <b>Вывод по разделу 1</b>
#
# Перед нами стоит задача классификации. За целевой признак берем столбец is_ultra. Остальные признаки помогут нам предсказывать решение по столбцу is_ultra.

# %% [markdown]
# ### 2. Разбиваем данные на выборки

# %%
train, test = train_test_split(df,test_size=0.4,random_state=42)
val, test = train_test_split(test,test_size=0.5,random_state=42)

print('Размер тренирующей выборки:', train.shape[0])
print('Размер валидационной выборки:', val.shape)
print('Размер тестовой выборки:', test.shape)
# Out:
# Размер тренирующей выборки: 1928
# Размер валидационной выборки: (643, 5)
# Размер тестовой выборки: (643, 5)

# %% [markdown]
# Составим таблицы признаков и целевого признака для каждого датасета

# %%
train_features = train.drop(['is_ultra'],axis=1)
train_target = train['is_ultra']

val_features = val.drop(['is_ultra'],axis=1)
val_target = val['is_ultra']

test_features = test.drop(['is_ultra'],axis=1)
test_target = test['is_ultra']

# %% [markdown]
# <b>Вывод по разделу 2:</b>
#
# Данные были разбиты по принципу 60/20/20.
#
# + Обучение пройдет на данных train.
# + Валидация модели на данных valid.
# + Лучшая модель по валидации будет применена на данных test.

# %% [markdown]
# ### 3.Исследуем модели

# %% [markdown]
# ####  3.1 Модель Дерева выбора.

# %% [markdown]
# Изменим в цикле гиперпараметр max_depth

# %%
# %%time

best_depth = 0
best_accuracy = 0

for depth in range(1,101):
    model = DecisionTreeClassifier(random_state=42, max_depth=depth)
    model.fit(train_features, train_target)
    val_predictions = model.predict(val_features)
    accuracy = accuracy_score(val_target, val_predictions)
    print('Глубина дерева', depth,'Точность',accuracy)
    if accuracy > best_accuracy:
        best_depth = depth
        best_accuracy = accuracy

print('Лучшая глубина дерева', best_depth,'Лучшая точность', best_accuracy)
# Out:
# Глубина дерева 1 Точность 0.7309486780715396
# Глубина дерева 2 Точность 0.7822706065318819
# Глубина дерева 3 Точность 0.7916018662519441
# Глубина дерева 4 Точность 0.7807153965785381
# Глубина дерева 5 Точность 0.7729393468118196
# Глубина дерева 6 Точность 0.776049766718507
# Глубина дерева 7 Точность 0.7807153965785381
# Глубина дерева 8 Точность 0.7962674961119751
# Глубина дерева 9 Точность 0.7807153965785381
# Глубина дерева 10 Точность 0.7947122861586314
# Глубина дерева 11 Точность 0.7853810264385692
# Глубина дерева 12 Точность 0.7869362363919129
# Глубина дерева 13 Точность 0.7791601866251944
# Глубина дерева 14 Точность 0.7713841368584758
# Глубина дерева 15 Точность 0.7682737169517885
# Глубина дерева 16 Точность 0.7620528771384136
# Глубина дерева 17 Точность 0.7511664074650077
# Глубина дерева 18 Точность 0.7558320373250389
# Глубина дерева 19 Точность 0.749611197511664
# Глубина дерева 20 Точность 0.7433903576982893
# Глубина дерева 21 Точность 0.7511664074650077
# Глубина дерева 22 Точность 0.7387247278382582
# Глубина дерева 23 Точность 0.7402799377916018
# Глубина дерева 24 Точность 0.7309486780715396
# Глубина дерева 25 Точность 0.7356143079315708
# Глубина дерева 26 Точность 0.7278382581648523
# Глубина дерева 27 Точность 0.7278382581648523
# Глубина дерева 28 Точность 0.7278382581648523
# Глубина дерева 29 Точность 0.7278382581648523
# Глубина дерева 30 Точность 0.7278382581648523
# Глубина дерева 31 Точность 0.7278382581648523
# Глубина дерева 32 Точность 0.7278382581648523
# Глубина дерева 33 Точность 0.7278382581648523
# Глубина дерева 34 Точность 0.7278382581648523
# Глубина дерева 35 Точность 0.7278382581648523
# Глубина дерева 36 Точность 0.7278382581648523
# Глубина дерева 37 Точность 0.7278382581648523
# Глубина дерева 38 Точность 0.7278382581648523
# Глубина дерева 39 Точность 0.7278382581648523
# Глубина дерева 40 Точность 0.7278382581648523
# Глубина дерева 41 Точность 0.7278382581648523
# Глубина дерева 42 Точность 0.7278382581648523
# Глубина дерева 43 Точность 0.7278382581648523
# Глубина дерева 44 Точность 0.7278382581648523
# Глубина дерева 45 Точность 0.7278382581648523
# Глубина дерева 46 Точность 0.7278382581648523
# Глубина дерева 47 Точность 0.7278382581648523
# Глубина дерева 48 Точность 0.7278382581648523
# Глубина дерева 49 Точность 0.7278382581648523
# Глубина дерева 50 Точность 0.7278382581648523
# Глубина дерева 51 Точность 0.7278382581648523
# Глубина дерева 52 Точность 0.7278382581648523
# Глубина дерева 53 Точность 0.7278382581648523
# Глубина дерева 54 Точность 0.7278382581648523
# Глубина дерева 55 Точность 0.7278382581648523
# Глубина дерева 56 Точность 0.7278382581648523
# Глубина дерева 57 Точность 0.7278382581648523
# Глубина дерева 58 Точность 0.7278382581648523
# Глубина дерева 59 Точность 0.7278382581648523
# Глубина дерева 60 Точность 0.7278382581648523
# Глубина дерева 61 Точность 0.7278382581648523
# Глубина дерева 62 Точность 0.7278382581648523
# Глубина дерева 63 Точность 0.7278382581648523
# Глубина дерева 64 Точность 0.7278382581648523
# Глубина дерева 65 Точность 0.7278382581648523
# Глубина дерева 66 Точность 0.7278382581648523
# Глубина дерева 67 Точность 0.7278382581648523
# Глубина дерева 68 Точность 0.7278382581648523
# Глубина дерева 69 Точность 0.7278382581648523
# Глубина дерева 70 Точность 0.7278382581648523
# Глубина дерева 71 Точность 0.7278382581648523
# Глубина дерева 72 Точность 0.7278382581648523
# Глубина дерева 73 Точность 0.7278382581648523
# Глубина дерева 74 Точность 0.7278382581648523
# Глубина дерева 75 Точность 0.7278382581648523
# Глубина дерева 76 Точность 0.7278382581648523
# Глубина дерева 77 Точность 0.7278382581648523
# Глубина дерева 78 Точность 0.7278382581648523
# Глубина дерева 79 Точность 0.7278382581648523
# Глубина дерева 80 Точность 0.7278382581648523
# Глубина дерева 81 Точность 0.7278382581648523
# Глубина дерева 82 Точность 0.7278382581648523
# Глубина дерева 83 Точность 0.7278382581648523
# Глубина дерева 84 Точность 0.7278382581648523
# Глубина дерева 85 Точность 0.7278382581648523
# Глубина дерева 86 Точность 0.7278382581648523
# Глубина дерева 87 Точность 0.7278382581648523
# Глубина дерева 88 Точность 0.7278382581648523
# Глубина дерева 89 Точность 0.7278382581648523
# Глубина дерева 90 Точность 0.7278382581648523
# Глубина дерева 91 Точность 0.7278382581648523
# Глубина дерева 92 Точность 0.7278382581648523
# Глубина дерева 93 Точность 0.7278382581648523
# Глубина дерева 94 Точность 0.7278382581648523
# Глубина дерева 95 Точность 0.7278382581648523
# Глубина дерева 96 Точность 0.7278382581648523
# Глубина дерева 97 Точность 0.7278382581648523
# Глубина дерева 98 Точность 0.7278382581648523
# Глубина дерева 99 Точность 0.7278382581648523
# Глубина дерева 100 Точность 0.7278382581648523
# Лучшая глубина дерева 8 Лучшая точность 0.7962674961119751
# Wall time: 689 ms

# %% [markdown]
# Можно было увеличить шаг для перебора, при увеличении глубины дерева на 1, качество почти не меняется.
#
# <b>Лучший показатель при глубине дерева 8.</b>

# %%
# %%time

best_tree_model = DecisionTreeClassifier(random_state=42, max_depth=8)
best_tree_model.fit(train_features, train_target)
val_predictions = best_tree_model.predict(val_features)
accuracy = accuracy_score(val_target, val_predictions)
print('Глубина дерева', 8,'Точность',accuracy)
# Out:
# Глубина дерева 8 Точность 0.7962674961119751
# Wall time: 6.26 ms

# %% [markdown]
# <b>Настроим гиперпараметр criterion с gini на entropy:</b>

# %%
# %%time

best_tree_model = DecisionTreeClassifier(random_state=42, max_depth=8, criterion="entropy")
best_tree_model.fit(train_features, train_target)
val_predictions = best_tree_model.predict(val_features)
accuracy = accuracy_score(val_target, val_predictions)
print('Глубина дерева', 8,'Точность',accuracy)
# Out:
# Глубина дерева 8 Точность 0.7900466562986003
# Wall time: 9.08 ms

# %% [markdown]
# Гиперпараметр gini показывает себя лучше.

# %% [markdown]
#  <b>Изменим splitter с best на random:</b>

# %%
# %%time

best_tree_model = DecisionTreeClassifier(random_state=42, max_depth=8, splitter='random')
best_tree_model.fit(train_features, train_target)
val_predictions = best_tree_model.predict(val_features)
accuracy = accuracy_score(val_target, val_predictions)
print('Глубина дерева', 8,'Точность',accuracy)
# Out:
# Глубина дерева 8 Точность 0.7698289269051322
# Wall time: 3.94 ms

# %% [markdown]
# Гиперпараметр best работает лучше.

# %% [markdown]
# #### 3.2 Модель Случайного леса

# %% [markdown]
#  Изменим в цикле гиперпараметр n_estimators.

# %%
# %%time

best_estim = 0
best_accuracy = 0

for estim in range(1,101):
    model = RandomForestClassifier(random_state=42, n_estimators=estim)
    model.fit(train_features, train_target)
    val_predictions = model.predict(val_features)
    accuracy = accuracy_score(val_target, val_predictions)
    print('Количество деревьев', estim,'Точность',accuracy)
    if accuracy > best_accuracy:
        best_estim = estim
        best_accuracy = accuracy

print('Лучшая количество деревьев', best_estim,'Лучшая точность', best_accuracy)
# Out:
# Количество деревьев 1 Точность 0.7153965785381027
# Количество деревьев 2 Точность 0.7698289269051322
# Количество деревьев 3 Точность 0.76049766718507
# Количество деревьев 4 Точность 0.7916018662519441
# Количество деревьев 5 Точность 0.7729393468118196
# Количество деревьев 6 Точность 0.7884914463452566
# Количество деревьев 7 Точность 0.7853810264385692
# Количество деревьев 8 Точность 0.7869362363919129
# Количество деревьев 9 Точность 0.7900466562986003
# Количество деревьев 10 Точность 0.7869362363919129
# Количество деревьев 11 Точность 0.7947122861586314
# Количество деревьев 12 Точность 0.7947122861586314
# Количество деревьев 13 Точность 0.7900466562986003
# Количество деревьев 14 Точность 0.7947122861586314
# Количество деревьев 15 Точность 0.7962674961119751
# Количество деревьев 16 Точность 0.7978227060653188
# Количество деревьев 17 Точность 0.7916018662519441
# Количество деревьев 18 Точность 0.7916018662519441
# Количество деревьев 19 Точность 0.7900466562986003
# Количество деревьев 20 Точность 0.7916018662519441
# Количество деревьев 21 Точность 0.7931570762052877
# Количество деревьев 22 Точность 0.7931570762052877
# Количество деревьев 23 Точность 0.7931570762052877
# Количество деревьев 24 Точность 0.7978227060653188
# Количество деревьев 25 Точность 0.7916018662519441
# Количество деревьев 26 Точность 0.7931570762052877
# Количество деревьев 27 Точность 0.7947122861586314
# Количество деревьев 28 Точность 0.7931570762052877
# Количество деревьев 29 Точность 0.7947122861586314
# Количество деревьев 30 Точность 0.7931570762052877
# Количество деревьев 31 Точность 0.7916018662519441
# Количество деревьев 32 Точность 0.7931570762052877
# Количество деревьев 33 Точность 0.7916018662519441
# Количество деревьев 34 Точность 0.7916018662519441
# Количество деревьев 35 Точность 0.7931570762052877
# Количество деревьев 36 Точность 0.7962674961119751
# Количество деревьев 37 Точность 0.7978227060653188
# Количество деревьев 38 Точность 0.7993779160186625
# Количество деревьев 39 Точность 0.7978227060653188
# Количество деревьев 40 Точность 0.7962674961119751
# Количество деревьев 41 Точность 0.7931570762052877
# Количество деревьев 42 Точность 0.7947122861586314
# Количество деревьев 43 Точность 0.7916018662519441
# Количество деревьев 44 Точность 0.7916018662519441
# Количество деревьев 45 Точность 0.7931570762052877
# Количество деревьев 46 Точность 0.7931570762052877
# Количество деревьев 47 Точность 0.7947122861586314
# Количество деревьев 48 Точность 0.7931570762052877
# Количество деревьев 49 Точность 0.7947122861586314
# Количество деревьев 50 Точность 0.7962674961119751
# Количество деревьев 51 Точность 0.7962674961119751
# Количество деревьев 52 Точность 0.7962674961119751
# Количество деревьев 53 Точность 0.7931570762052877
# Количество деревьев 54 Точность 0.7993779160186625
# Количество деревьев 55 Точность 0.7947122861586314
# Количество деревьев 56 Точность 0.7947122861586314
# Количество деревьев 57 Точность 0.7962674961119751
# Количество деревьев 58 Точность 0.7931570762052877
# Количество деревьев 59 Точность 0.7947122861586314
# Количество деревьев 60 Точность 0.7962674961119751
# Количество деревьев 61 Точность 0.7962674961119751
# Количество деревьев 62 Точность 0.7993779160186625
# Количество деревьев 63 Точность 0.7993779160186625
# Количество деревьев 64 Точность 0.8009331259720062
# Количество деревьев 65 Точность 0.7993779160186625
# Количество деревьев 66 Точность 0.7993779160186625
# Количество деревьев 67 Точность 0.7978227060653188
# Количество деревьев 68 Точность 0.7978227060653188
# Количество деревьев 69 Точность 0.7978227060653188
# Количество деревьев 70 Точность 0.7978227060653188
# Количество деревьев 71 Точность 0.7978227060653188
# Количество деревьев 72 Точность 0.7993779160186625
# Количество деревьев 73 Точность 0.8009331259720062
# Количество деревьев 74 Точность 0.8009331259720062
# Количество деревьев 75 Точность 0.80248833592535
# Количество деревьев 76 Точность 0.8040435458786936
# Количество деревьев 77 Точность 0.80248833592535
# Количество деревьев 78 Точность 0.8009331259720062
# Количество деревьев 79 Точность 0.7993779160186625
# Количество деревьев 80 Точность 0.8009331259720062
# Количество деревьев 81 Точность 0.80248833592535
# Количество деревьев 82 Точность 0.8009331259720062
# Количество деревьев 83 Точность 0.8040435458786936
# Количество деревьев 84 Точность 0.8040435458786936
# Количество деревьев 85 Точность 0.80248833592535
# Количество деревьев 86 Точность 0.80248833592535
# Количество деревьев 87 Точность 0.80248833592535
# Количество деревьев 88 Точность 0.80248833592535
# Количество деревьев 89 Точность 0.8040435458786936
# Количество деревьев 90 Точность 0.80248833592535
# Количество деревьев 91 Точность 0.8055987558320373
# Количество деревьев 92 Точность 0.80248833592535
# Количество деревьев 93 Точность 0.8055987558320373
# Количество деревьев 94 Точность 0.8040435458786936
# Количество деревьев 95 Точность 0.8055987558320373
# Количество деревьев 96 Точность 0.8055987558320373
# Количество деревьев 97 Точность 0.8040435458786936
# Количество деревьев 98 Точность 0.8040435458786936
# Количество деревьев 99 Точность 0.80248833592535
# Количество деревьев 100 Точность 0.80248833592535
# Лучшая количество деревьев 91 Лучшая точность 0.8055987558320373
# Wall time: 13.7 s

# %%
# %%time

best_forest_model = RandomForestClassifier(random_state=42, n_estimators=91)
best_forest_model.fit(train_features, train_target)
val_predictions = best_forest_model.predict(val_features)
accuracy = accuracy_score(val_target, val_predictions)
print('Количество деревьев', 91,'Точность',accuracy)
# Out:
# Количество деревьев 91 Точность 0.8055987558320373
# Wall time: 244 ms

# %% [markdown]
# <b>Настроим гиперпараметр criterion с gini на entropy:</b>

# %%
model = RandomForestClassifier(random_state=42, n_estimators=91, criterion='entropy')
model.fit(train_features, train_target)
val_predictions = model.predict(val_features)
accuracy = accuracy_score(val_target, val_predictions)
print('Количество деревьев', estim,'Точность',accuracy)
# Out:
# Количество деревьев 100 Точность 0.8087091757387247

# %% [markdown]
# Гиперпараметр entropy показывает себя лучше.

# %% [markdown]
# <b>Изменим bootstrap с True на Flase:

# %%
model = RandomForestClassifier(random_state=42, n_estimators=91, bootstrap=False)
model.fit(train_features, train_target)
val_predictions = model.predict(val_features)
accuracy = accuracy_score(val_target, val_predictions)
print('Количество деревьев', estim,'Точность',accuracy)
# Out:
# Количество деревьев 100 Точность 0.7776049766718507

# %% [markdown]
# bootstrap с True показывает себя лучше.

# %% [markdown]
# <b>Изменим warm_start с False на True:

# %%
model = RandomForestClassifier(random_state=42, n_estimators=91, warm_start=True)
model.fit(train_features, train_target)
val_predictions = model.predict(val_features)
accuracy = accuracy_score(val_target, val_predictions)
print('Количество деревьев', estim,'Точность',accuracy)
# Out:
# Количество деревьев 100 Точность 0.8055987558320373

# %% [markdown]
# Значения не изменились.

# %% [markdown]
# <b>Модель с данными гиперпараметрами лучшая:

# %%
model = RandomForestClassifier(random_state=42, n_estimators=91, criterion='entropy')
model.fit(train_features, train_target)
val_predictions = model.predict(val_features)
accuracy = accuracy_score(val_target, val_predictions)
print('Количество деревьев', estim,'Точность',accuracy)
# Out:
# Количество деревьев 100 Точность 0.8087091757387247

# %% [markdown]
# #### 3.3 Модель на основе логистической регрессии

# %% [markdown]
# Изменим гипер параметр max_iter в цикле.

# %%
# %%time

best_max_iter = 0
best_accuracy = 0

for max_iter in range(1, 201):
    model = LogisticRegression(random_state=42, max_iter=max_iter)
    model.fit(train_features, train_target)
    val_predictions = model.predict(val_features)
    accuracy = accuracy_score(val_target, val_predictions)
    print('Количество итерраций', max_iter,'Точность',accuracy)
    if accuracy > best_accuracy:
        best_max_iter = max_iter
        best_accuracy = accuracy

print('Лучшая количество итерраций', best_max_iter,'Лучшая точность', best_accuracy)
# Out:
# Количество итерраций 1 Точность 0.6936236391912908
# Количество итерраций 2 Точность 0.6936236391912908
# Количество итерраций 3 Точность 0.6936236391912908
# Количество итерраций 4 Точность 0.6936236391912908
# Количество итерраций 5 Точность 0.6936236391912908
# Количество итерраций 6 Точность 0.6936236391912908
# Количество итерраций 7 Точность 0.6936236391912908
# Количество итерраций 8 Точность 0.6936236391912908
# Количество итерраций 9 Точность 0.6936236391912908
# Количество итерраций 10 Точность 0.6936236391912908
# Количество итерраций 11 Точность 0.6936236391912908
# Количество итерраций 12 Точность 0.6936236391912908
# Количество итерраций 13 Точность 0.6936236391912908
# Количество итерраций 14 Точность 0.6936236391912908
# Количество итерраций 15 Точность 0.6936236391912908
# Количество итерраций 16 Точность 0.6936236391912908
# Количество итерраций 17 Точность 0.6936236391912908
# Количество итерраций 18 Точность 0.6936236391912908
# Количество итерраций 19 Точность 0.6936236391912908
# Количество итерраций 20 Точность 0.6936236391912908
# Количество итерраций 21 Точность 0.6951788491446346
# Количество итерраций 22 Точность 0.6982892690513219
# Количество итерраций 23 Точность 0.6982892690513219
# Количество итерраций 24 Точность 0.71850699844479
# Количество итерраций 25 Точность 0.7278382581648523
# Количество итерраций 26 Точность 0.7216174183514774
# Количество итерраций 27 Точность 0.7262830482115086
# Количество итерраций 28 Точность 0.7262830482115086
# Количество итерраций 29 Точность 0.7262830482115086
# Количество итерраций 30 Точность 0.7262830482115086
# Количество итерраций 31 Точность 0.7262830482115086
# Количество итерраций 32 Точность 0.7262830482115086
# Количество итерраций 33 Точность 0.7262830482115086
# Количество итерраций 34 Точность 0.7262830482115086
# Количество итерраций 35 Точность 0.7262830482115086
# Количество итерраций 36 Точность 0.7262830482115086
# Количество итерраций 37 Точность 0.7262830482115086
# Количество итерраций 38 Точность 0.7262830482115086
# Количество итерраций 39 Точность 0.7231726283048211
# Количество итерраций 40 Точность 0.7231726283048211
# Количество итерраций 41 Точность 0.7216174183514774
# Количество итерраций 42 Точность 0.7231726283048211
# Количество итерраций 43 Точность 0.7231726283048211
# Количество итерраций 44 Точность 0.7247278382581649
# Количество итерраций 45 Точность 0.7200622083981337
# Количество итерраций 46 Точность 0.71850699844479
# Количество итерраций 47 Точность 0.71850699844479
# Количество итерраций 48 Точность 0.7200622083981337
# Количество итерраций 49 Точность 0.7200622083981337
# Количество итерраций 50 Точность 0.7200622083981337
# Количество итерраций 51 Точность 0.7200622083981337
# Количество итерраций 52 Точность 0.7200622083981337
# Количество итерраций 53 Точность 0.7200622083981337
# Количество итерраций 54 Точность 0.7200622083981337
# Количество итерраций 55 Точность 0.7200622083981337
# Количество итерраций 56 Точность 0.7200622083981337
# Количество итерраций 57 Точность 0.71850699844479
# Количество итерраций 58 Точность 0.71850699844479
# Количество итерраций 59 Точность 0.71850699844479
# Количество итерраций 60 Точность 0.71850699844479
# Количество итерраций 61 Точность 0.71850699844479
# Количество итерраций 62 Точность 0.71850699844479
# Количество итерраций 63 Точность 0.71850699844479
# Количество итерраций 64 Точность 0.7153965785381027
# Количество итерраций 65 Точность 0.713841368584759
# Количество итерраций 66 Точность 0.7107309486780715
# Количество итерраций 67 Точность 0.7107309486780715
# Количество итерраций 68 Точность 0.7107309486780715
# Количество итерраций 69 Точность 0.7045101088646968
# Количество итерраций 70 Точность 0.7045101088646968
# Количество итерраций 71 Точность 0.7122861586314152
# Количество итерраций 72 Точность 0.6998444790046656
# Количество итерраций 73 Точность 0.6998444790046656
# Количество итерраций 74 Точность 0.6967340590979783
# Количество итерраций 75 Точность 0.6905132192846034
# Количество итерраций 76 Точность 0.7060653188180405
# Количество итерраций 77 Точность 0.713841368584759
# Количество итерраций 78 Точность 0.7045101088646968
# Количество итерраций 79 Точность 0.7013996889580093
# Количество итерраций 80 Точность 0.7013996889580093
# Количество итерраций 81 Точность 0.7013996889580093
# Количество итерраций 82 Точность 0.6905132192846034
# Количество итерраций 83 Точность 0.6905132192846034
# Количество итерраций 84 Точность 0.6905132192846034
# Количество итерраций 85 Точность 0.6936236391912908
# Количество итерраций 86 Точность 0.6982892690513219
# Количество итерраций 87 Точность 0.6920684292379471
# Количество итерраций 88 Точность 0.6951788491446346
# Количество итерраций 89 Точность 0.6936236391912908
# Количество итерраций 90 Точность 0.7200622083981337
# Количество итерраций 91 Точность 0.7216174183514774
# Количество итерраций 92 Точность 0.7200622083981337
# Количество итерраций 93 Точность 0.7293934681181959
# Количество итерраций 94 Точность 0.7247278382581649
# Количество итерраций 95 Точность 0.7293934681181959
# Количество итерраций 96 Точность 0.7325038880248833
# Количество итерраций 97 Точность 0.7371695178849145
# Количество итерраций 98 Точность 0.7402799377916018
# Количество итерраций 99 Точность 0.7402799377916018
# Количество итерраций 100 Точность 0.7402799377916018
# Количество итерраций 101 Точность 0.7402799377916018
# Количество итерраций 102 Точность 0.7402799377916018
# Количество итерраций 103 Точность 0.7402799377916018
# Количество итерраций 104 Точность 0.7402799377916018
# Количество итерраций 105 Точность 0.7402799377916018
# Количество итерраций 106 Точность 0.7402799377916018
# Количество итерраций 107 Точность 0.7402799377916018
# Количество итерраций 108 Точность 0.7402799377916018
# Количество итерраций 109 Точность 0.7402799377916018
# Количество итерраций 110 Точность 0.7402799377916018
# Количество итерраций 111 Точность 0.7402799377916018
# Количество итерраций 112 Точность 0.7402799377916018
# Количество итерраций 113 Точность 0.7402799377916018
# Количество итерраций 114 Точность 0.7402799377916018
# Количество итерраций 115 Точность 0.7402799377916018
# Количество итерраций 116 Точность 0.7402799377916018
# Количество итерраций 117 Точность 0.7402799377916018
# Количество итерраций 118 Точность 0.7402799377916018
# Количество итерраций 119 Точность 0.7402799377916018
# Количество итерраций 120 Точность 0.7402799377916018
# Количество итерраций 121 Точность 0.7402799377916018
# Количество итерраций 122 Точность 0.7402799377916018
# Количество итерраций 123 Точность 0.7402799377916018
# Количество итерраций 124 Точность 0.7402799377916018
# Количество итерраций 125 Точность 0.7402799377916018
# Количество итерраций 126 Точность 0.7402799377916018
# Количество итерраций 127 Точность 0.7402799377916018
# Количество итерраций 128 Точность 0.7402799377916018
# Количество итерраций 129 Точность 0.7402799377916018
# Количество итерраций 130 Точность 0.7402799377916018
# Количество итерраций 131 Точность 0.7402799377916018
# Количество итерраций 132 Точность 0.7402799377916018
# Количество итерраций 133 Точность 0.7402799377916018
# Количество итерраций 134 Точность 0.7402799377916018
# Количество итерраций 135 Точность 0.7402799377916018
# Количество итерраций 136 Точность 0.7402799377916018
# Количество итерраций 137 Точность 0.7402799377916018
# Количество итерраций 138 Точность 0.7402799377916018
# Количество итерраций 139 Точность 0.7402799377916018
# Количество итерраций 140 Точность 0.7402799377916018
# Количество итерраций 141 Точность 0.7402799377916018
# Количество итерраций 142 Точность 0.7402799377916018
# Количество итерраций 143 Точность 0.7402799377916018
# Количество итерраций 144 Точность 0.7402799377916018
# Количество итерраций 145 Точность 0.7402799377916018
# Количество итерраций 146 Точность 0.7402799377916018
# Количество итерраций 147 Точность 0.7402799377916018
# Количество итерраций 148 Точность 0.7402799377916018
# Количество итерраций 149 Точность 0.7402799377916018
# Количество итерраций 150 Точность 0.7402799377916018
# Количество итерраций 151 Точность 0.7402799377916018
# Количество итерраций 152 Точность 0.7402799377916018
# Количество итерраций 153 Точность 0.7402799377916018
# Количество итерраций 154 Точность 0.7402799377916018
# Количество итерраций 155 Точность 0.7402799377916018
# Количество итерраций 156 Точность 0.7402799377916018
# Количество итерраций 157 Точность 0.7402799377916018
# Количество итерраций 158 Точность 0.7402799377916018
# Количество итерраций 159 Точность 0.7402799377916018
# Количество итерраций 160 Точность 0.7402799377916018
# Количество итерраций 161 Точность 0.7402799377916018
# Количество итерраций 162 Точность 0.7402799377916018
# Количество итерраций 163 Точность 0.7402799377916018
# Количество итерраций 164 Точность 0.7402799377916018
# Количество итерраций 165 Точность 0.7402799377916018
# Количество итерраций 166 Точность 0.7402799377916018
# Количество итерраций 167 Точность 0.7402799377916018
# Количество итерраций 168 Точность 0.7402799377916018
# Количество итерраций 169 Точность 0.7402799377916018
# Количество итерраций 170 Точность 0.7402799377916018
# Количество итерраций 171 Точность 0.7402799377916018
# Количество итерраций 172 Точность 0.7402799377916018
# Количество итерраций 173 Точность 0.7402799377916018
# Количество итерраций 174 Точность 0.7402799377916018
# Количество итерраций 175 Точность 0.7402799377916018
# Количество итерраций 176 Точность 0.7402799377916018
# Количество итерраций 177 Точность 0.7402799377916018
# Количество итерраций 178 Точность 0.7402799377916018
# Количество итерраций 179 Точность 0.7402799377916018
# Количество итерраций 180 Точность 0.7402799377916018
# Количество итерраций 181 Точность 0.7402799377916018
# Количество итерраций 182 Точность 0.7402799377916018
# Количество итерраций 183 Точность 0.7402799377916018
# Количество итерраций 184 Точность 0.7402799377916018
# Количество итерраций 185 Точность 0.7402799377916018
# Количество итерраций 186 Точность 0.7402799377916018
# Количество итерраций 187 Точность 0.7402799377916018
# Количество итерраций 188 Точность 0.7402799377916018
# Количество итерраций 189 Точность 0.7402799377916018
# Количество итерраций 190 Точность 0.7402799377916018
# Количество итерраций 191 Точность 0.7402799377916018
# Количество итерраций 192 Точность 0.7402799377916018
# Количество итерраций 193 Точность 0.7402799377916018
# Количество итерраций 194 Точность 0.7402799377916018
# Количество итерраций 195 Точность 0.7402799377916018
# Количество итерраций 196 Точность 0.7402799377916018
# Количество итерраций 197 Точность 0.7402799377916018
# Количество итерраций 198 Точность 0.7402799377916018
# Количество итерраций 199 Точность 0.7402799377916018
# Количество итерраций 200 Точность 0.7402799377916018
# Лучшая количество итерраций 98 Лучшая точность 0.7402799377916018
# Wall time: 2.75 s

# %%
# %%time

best_reg_model = LogisticRegression(random_state=42,max_iter=100)
best_reg_model.fit(train_features, train_target)
val_predictions = best_reg_model.predict(val_features)
accuracy = accuracy_score(val_target, val_predictions)
print('Количество итерраций',98 ,'Точность',accuracy)
# Out:
# Количество итерраций 98 Точность 0.7402799377916018
# Wall time: 17.8 ms

# %% [markdown]
# Значение по-умолчанию в max_iter=100 хорошее. Увеличение в большую сторону ничего не поменяет.

# %% [markdown]
# <b>Изменим гиперпараметр solver.

# %%
# %%time

best_solver = ''
best_accuracy = 0

for solve in {'newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'}:
    model = LogisticRegression(random_state=42, solver=solve)
    model.fit(train_features, train_target)
    val_predictions = model.predict(val_features)
    accuracy = accuracy_score(val_target, val_predictions)
    print('Solver', solve,'Точность',accuracy)
    if accuracy > best_accuracy:
        best_solver= solve
        best_accuracy = accuracy

print('Лучший solver', best_solver,'Лучшая точность', best_accuracy)
# Out:
# Solver lbfgs Точность 0.7402799377916018
# Solver sag Точность 0.6982892690513219
# Solver liblinear Точность 0.7200622083981337
# Solver newton-cg Точность 0.7402799377916018
# Solver saga Точность 0.6951788491446346
# Лучший solver lbfgs Лучшая точность 0.7402799377916018
# Wall time: 97.3 ms

# %% [markdown]
# Лучшим solver является lbfgs, который стоит по-умолчанию. На равне с ним newton-cg.

# %% [markdown]
# <b>Изменим в цикле гиперпараметр С.

# %%
# %%time

best_C = 0.0
best_accuracy = 0

for float_c in [x/10 for x in range(1,21)]:
    model = LogisticRegression(random_state=42, C=float_c)
    model.fit(train_features, train_target)
    val_predictions = model.predict(val_features)
    accuracy = accuracy_score(val_target, val_predictions)
    print('C=', float_c,'Точность',accuracy)
    if accuracy > best_accuracy:
        best_C= float_c
        best_accuracy = accuracy

print('Лучший C', best_C,'Лучшая точность', best_accuracy)
# Out:
# C= 0.1 Точность 0.71850699844479
# C= 0.2 Точность 0.7402799377916018
# C= 0.3 Точность 0.7402799377916018
# C= 0.4 Точность 0.7402799377916018
# C= 0.5 Точность 0.71850699844479
# C= 0.6 Точность 0.71850699844479
# C= 0.7 Точность 0.7418351477449455
# C= 0.8 Точность 0.71850699844479
# C= 0.9 Точность 0.7402799377916018
# C= 1.0 Точность 0.7402799377916018
# C= 1.1 Точность 0.7371695178849145
# C= 1.2 Точность 0.71850699844479
# C= 1.3 Точность 0.71850699844479
# C= 1.4 Точность 0.71850699844479
# C= 1.5 Точность 0.71850699844479
# C= 1.6 Точность 0.71850699844479
# C= 1.7 Точность 0.71850699844479
# C= 1.8 Точность 0.71850699844479
# C= 1.9 Точность 0.71850699844479
# C= 2.0 Точность 0.71850699844479
# Лучший C 0.7 Лучшая точность 0.7418351477449455
# Wall time: 269 ms

# %% [markdown]
# Значение C=0.7 показывает лучший результат (по умолчанию С=1).

# %% [markdown]
# <b>Вывод по разделу 3:

# %% [markdown]
# В ходе исследования были получены следующие данные:
#
# + Точность модели решающего дерева при глубине 8 равна 0.796. Время выполнения код и обучения 0,677 секунд.
# + Точность модели случайного леса при количестве деревьев 18 равна 0.809. Время выполнения код и обучения 13,8 секунд.
# + Точность модели логистической регресии равна 0.742. Время выполнения код и обучения 2,79 секунд.
#
# Лучший результат показывает модель случайного леса с гиперпараметроми n_estimators=91 и criterion=entropy.

# %% [markdown]
# ### 4. Проверка модели на тестовой выборке:

# %% [markdown]
# Оценим точность каждой модели на тестовой выборке:

# %%
test_predictions = best_tree_model.predict(test_features)
accuracy = accuracy_score(test_target, test_predictions)
print('Точность модели решающего леса на тестовой выборке',accuracy)

test_predictions = best_forest_model.predict(test_features)
accuracy = accuracy_score(test_target, test_predictions)
print('Точность модели случайного леса на тестовой выборке',accuracy)

test_predictions = best_reg_model.predict(test_features)
accuracy = accuracy_score(test_target, test_predictions)
print('Точность модели логистической регресиии на тестовой выборке',accuracy)
# Out:
# Точность модели решающего леса на тестовой выборке 0.7993779160186625
# Точность модели случайного леса на тестовой выборке 0.8102643856920684
# Точность модели логистической регресиии на тестовой выборке 0.7682737169517885

# %% [markdown]
# <b>Вывод по разделу 4:

# %% [markdown]
# Для решения поставленной задачи можно выбрать модель случайного леса с поправкой, что точность 0.81 достигается округлением до сотых значения 0.8102643856920684.

# %% [markdown]
# ### 5.Прверка модели на адекватность:

# %% [markdown]
# Оценить адекватность модели можно используя несколько метрик:
#
# + accuracy - точность совпадения прогнозов с правильными ответами.
# + precision - отношение правильно предсказанных классов равных 1(TP) к сумме правильно предсказанных классов равных 1(TP) с неправльными предсказаниями, указанные как 1(FP).
# + recall - отношение правильно предсказанных классов равных 1(TP) к сумме правильно предсказанных классов равных 1(TP) с неправльными предсказаниями, указанные как 0(FN).

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %%
test_predictions = best_forest_model.predict(test_features)
accuracy = accuracy_score(test_target, test_predictions)
precision = precision_score(test_target, test_predictions)
recall = recall_score(test_target, test_predictions)
print('Accuracy =', accuracy, 'Precision =', precision, 'Recall =', recall)
# Out:
# Accuracy = 0.8102643856920684 Precision = 0.732484076433121 Recall = 0.5897435897435898

# %% [markdown]
# Для оценки адеватности используется F-мера - среднее гармоническое между precision и recall. Если хотя бы один из параметров близок к нулю, то и F-мера стремится к 0. Если оба стремятся к 1, то F-мера тоже стремится к 1.

# %%
f_score = f1_score(test_target, test_predictions)
print('F-мера =', f_score)
# Out:
# F-мера = 0.6534090909090909

# %% [markdown]
# <b>Вывод по разделу 5:

# %% [markdown]
# Адекватность модели оценивается по нескольким параметрам. Для модели классификации это accuracy, precision и recall. Качество модели лучше всего отражают precision и recall и эти метрики складываются в F-мера как единую оценку модели.
#
# Модель получилась среднего качества. И для таких задач она адекватна.

# %% [markdown]
# ### Итоговый вывод:

# %% [markdown]
# В ходе проделанной работы было выполнено:
#
# 1. Изучен файл с данными.
# 2. Разбиты данные на три выборки: обучающая, валидационная и тестовая.
# 3. Исследованы три модели классификации: Решающее дерево, Случайный лес и Логистическая регрессия.
# 4. Найдены оптимальные параметры для каждой модели и выбрана одна из них для обучения модели.
# 5. Оценена точность обученной модели.
# 6. Оценена адекватность модели.
#
# Для обучения модели было использована выборка в 2000 значений. Этого может быть недостаточно для повышения ключевых параметров модели классификатора. Увеличение в 10 или 100 увеличит accuracy, precision и recall, а также время обучения.
#
# Адекватность модели повышается с ростом количества значений.
